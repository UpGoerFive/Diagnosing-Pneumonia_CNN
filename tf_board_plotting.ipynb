# %% [markdown]
# ## Getting Train-Validation Plots for the Presentation
#
# If you'd like to run this notebook, you'll need to download the csv versions of the logs to plot from tensorboard.

# %%
from modelplotting import tf_board_plots, plot_models

ploting_list = [({'Train': 'logs/plotting/run-baseline20220217-155427_train-tag-epoch_acc.csv',
                  'Validation': 'logs/plotting/run-baseline20220217-155427_validation-tag-epoch_acc.csv'}, ('Baseline', 'Accuracy')),
                ({'Train': 'logs/plotting/run-baseline20220217-155427_train-tag-epoch_recall.csv',
                  'Validation': 'logs/plotting/run-baseline20220217-155427_validation-tag-epoch_recall.csv'}, ('Baseline', 'Recall')),
                ({'Train': 'logs/plotting/run-second-aug20220216-201402_train-tag-epoch_acc.csv',
                  'Validation': 'logs/plotting/run-second-aug20220216-201402_validation-tag-epoch_acc.csv'}, ('Image_Augmentation', 'Accuracy')),
                ({'Train': 'logs/plotting/run-second-aug20220216-201402_train-tag-epoch_recall_3.csv',
                  'Validation': 'logs/plotting/run-second-aug20220216-201402_validation-tag-epoch_recall_3.csv'}, ('Image_Augmentation', 'Recall')),
                ({'Train': 'logs/plotting/run-long_run20220217-010619_train-tag-epoch_acc.csv',
                  'Validation': 'logs/plotting/run-long_run20220217-010619_validation-tag-epoch_acc.csv'}, ('Long_Run', 'Accuracy')),
                ({'Train': 'logs/plotting/run-long_run20220217-010619_train-tag-epoch_recall_12.csv',
                  'Validation': 'logs/plotting/run-long_run20220217-010619_validation-tag-epoch_recall_12.csv'}, ('Long_Run', 'Recall'))]

tf_board_plots(ploting_list)
